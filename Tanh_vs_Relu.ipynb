# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8185 - loss: 0.5129 - val_accuracy: 0.8583 - val_loss: 0.3951
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8618 - loss: 0.3770 - val_accuracy: 0.8714 - val_loss: 0.3527
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8755 - loss: 0.3381 - val_accuracy: 0.8722 - val_loss: 0.3563
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8843 - loss: 0.3123 - val_accuracy: 0.8812 - val_loss: 0.3275
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8898 - loss: 0.2963 - val_accuracy: 0.8837 - val_loss: 0.3266
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8960 - loss: 0.2796 - val_accuracy: 0.8792 - val_loss: 0.3371
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8995 - loss: 0.2688 - val_accuracy: 0.8851 - val_loss: 0.3218
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9026 - loss: 0.2585 - val_accuracy: 0.8792 - val_loss: 0.3331
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9072 - loss: 0.2476 - val_accuracy: 0.8880 - val_loss: 0.3174
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9098 - loss: 0.2377 - val_accuracy: 0.8879 - val_loss: 0.3248

# %%
eval = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8802 - loss: 0.3477

# %%
print(eval)
# Out:
# [0.34774261713027954, 0.8802000284194946]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2)

axes[0].plot(model_history.history['accuracy'])
axes[0].set_title("Model accuracy")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Accuracy")

axes[1].plot(model_history.history['loss'])
axes[1].set_title("Model loss")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
model2 = keras.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='tanh'),
    layers.Dense(64, activation='tanh'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_history2 = model2.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8256 - loss: 0.4841 - val_accuracy: 0.8441 - val_loss: 0.4278
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8627 - loss: 0.3719 - val_accuracy: 0.8467 - val_loss: 0.4140
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8741 - loss: 0.3388 - val_accuracy: 0.8745 - val_loss: 0.3457
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8830 - loss: 0.3161 - val_accuracy: 0.8788 - val_loss: 0.3388
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8883 - loss: 0.2997 - val_accuracy: 0.8849 - val_loss: 0.3218
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8936 - loss: 0.2855 - val_accuracy: 0.8767 - val_loss: 0.3441
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8983 - loss: 0.2752 - val_accuracy: 0.8797 - val_loss: 0.3393
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9005 - loss: 0.2654 - val_accuracy: 0.8848 - val_loss: 0.3176
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9052 - loss: 0.2542 - val_accuracy: 0.8837 - val_loss: 0.3278
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9099 - loss: 0.2443 - val_accuracy: 0.8845 - val_loss: 0.3226

# %%
eval2 = model2.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8753 - loss: 0.3537

# %%
print(eval2)
# Out:
# [0.353719025850296, 0.8752999901771545]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2)

axes[0].plot(model_history2.history['accuracy'])
axes[0].set_title("Model accuracy")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Accuracy")

axes[1].plot(model_history2.history['loss'])
axes[1].set_title("Model loss")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')
